# %% [markdown]
# # Transformer Encoder 学习笔记
#
# 状态：尚未开始。本 Notebook 只是学习骨架，不包含完整实现。

# %% [markdown]
# ## 1. 问题抽象
#
# 在确定正式的输入、输出与框架约定后补充。

# %% [markdown]
# ## 2. 我的初始理解
#
# 从 Q / K / V 与缩放点积注意力开始。在组合多个注意力头或编码器层之前，先明确记录每个张量的形状。

# %% [markdown]
# ## 3. 算法拆解
#
# 计划顺序：Q/K/V 投影、缩放点积注意力、自注意力、多头注意力、FFN、残差连接、LayerNorm、单个 Encoder Layer，最后组合 Multi-Layer Encoder。

# %% [markdown]
# ## 4. 关键公式 / Tensor Shape
#
# 编码前先在这里记录 batch、sequence、model、head 与 per-head 维度。

# %% [markdown]
# ## 5. 伪代码
#
# 在组件约定确定后补充。

# %% [markdown]
# ## 6. 分步实现
#
# 先从相互独立的投影测试与形状测试开始，不直接跳到完整 Encoder 实现。

# %% [markdown]
# ## 7. 已发现的错误
#
# 尚未进行 Attempt。

# %% [markdown]
# ## 8. 学到的 Python 模式
#
# 尚未进行 Attempt。

# %% [markdown]
# ## 9. 最终理解
#
# 在完成实现与测试后补充。

# %% [markdown]
# ## 10. 复习记录
#
# 第一次 Attempt 完成前暂不安排复习。
