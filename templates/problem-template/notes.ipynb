# %% [markdown]
# # 题目学习笔记

# %% [markdown]
# ## 1. 问题抽象

# %% [markdown]
# ## 2. 我的初始理解

# %% [markdown]
# ## 3. 算法拆解

# %% [markdown]
# ## 4. 关键公式 / Tensor Shape

# %% [markdown]
# ## 5. 伪代码

# %% [markdown]
# ## 6. 分步实现

# %% [markdown]
# ## 7. 已发现的错误

# %% [markdown]
# ## 8. 学到的 Python 模式

# %% [markdown]
# ## 9. 最终理解

# %% [markdown]
# ## 10. 复习记录
